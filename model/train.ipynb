# %% [markdown]
# ### Multi-task TRANSUnet for segmentation and classification

# %%
import cv2
import numpy as np
import pandas as pd
import os
from glob import glob
import random
from collections import defaultdict, Counter
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
from tensorflow.keras import layers, Model, regularizers
from tensorflow.keras.metrics import Recall, Precision, Accuracy, IoU
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
import tensorflow.keras.backend as K
from sklearn.model_selection import KFold
import re
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
masterlist_path = '/content/drive/MyDrive/MasterlistAug30-2017.xlsx'
df = pd.read_excel(masterlist_path)

outcome_counts = df['Outcome'].value_counts()
print("Outcome distribution:\n", outcome_counts)
print("Outcome:\n0 not implanted\n1 implanted\n2 unknown")
df = df[df['Outcome'] != 2]
image_to_outcome = dict(zip(df['File Name'], df['Outcome']))
print(image_to_outcome)
outcome_counts = df['Outcome'].value_counts()

def get_outcome_from_path(path):
    fname = os.path.basename(path)
    base_fname = os.path.splitext(fname)[0]
    # Remove trailing aug index, if exists
    base_key = re.sub(r'_\d+$', '', base_fname)
    outcome = image_to_outcome.get(base_key, None)
    if outcome is None or pd.isna(outcome):
        pass
    return outcome
# Out:
# Outcome distribution:
#  Outcome
# 1.0    96
# 2.0    78
# 0.0    75
# Name: count, dtype: int64
# Outcome:
# 0 not implanted
# 1 implanted
# 2 unknown
# {nan: nan, 'Blast_PCRM_R12-0137': 1.0, 'Blast_PCRM_R12-0160': 1.0, 'Blast_PCRM_R12-0173a': 0.0, 'Blast_PCRM_R12-0173b': 0.0, 'Blast_PCRM_R12-0221a': 1.0, 'Blast_PCRM_R12-0221b': 1.0, 'Blast_PCRM_R12-0223a': 1.0, 'Blast_PCRM_R12-0223b': 1.0, 'Blast_PCRM_R12-0236': 1.0, 'Blast_PCRM_R12-0254b': 0.0, 'Blast_PCRM_R12-0259': 1.0, 'Blast_PCRM_R12-0266': 1.0, 'Blast_PCRM_R12-0268a': 1.0, 'Blast_PCRM_R12-0268b': 1.0, 'Blast_PCRM_R12-0293a': 0.0, 'Blast_PCRM_R12-0296': 1.0, 'Blast_PCRM_R12-0306a': 0.0, 'Blast_PCRM_R12-0306b': 0.0, 'Blast_PCRM_R12-0315': 0.0, 'Blast_PCRM_R12-0316a': 1.0, 'Blast_PCRM_R12-0316b': 1.0, 'Blast_PCRM_R12-0326b': 1.0, 'Blast_PCRM_R12-0335': 1.0, 'Blast_PCRM_R12-0338a': 0.0, 'Blast_PCRM_R12-0338b': 0.0, 'Blast_PCRM_R12-0347a': 1.0, 'Blast_PCRM_R12-0348a': 1.0, 'Blast_PCRM_R12-0354': 0.0, 'Blast_PCRM_R12-0358a': 0.0, 'Blast_PCRM_R12-0358b': 0.0, 'Blast_PCRM_R12-0397a': 0.0, 'Blast_PCRM_R12-0397b': 0.0, 'Blast_PCRM_R12-0463a': 1.0, 'Blast_PCRM_R12-0463b': 1.0, 'Blast_PCRM_R12-0464b': 1.0, 'Blast_PCRM_R12-0499a': 1.0, 'Blast_PCRM_R12-0499b': 1.0, 'Blast_PCRM_R12-0508a': 1.0, 'Blast_PCRM_R12-0508b': 1.0, 'Blast_PCRM_R12-0519b': 0.0, 'Blast_PCRM_R13-0005': 0.0, 'Blast_PCRM_R13-0014A': 0.0, 'Blast_PCRM_R13-0018a': 0.0, 'Blast_PCRM_R13-0019': 0.0, 'Blast_PCRM_R13-0026': 1.0, 'Blast_PCRM_R13-0027': 1.0, 'Blast_PCRM_R13-0052A': 0.0, 'Blast_PCRM_R13-0052B': 0.0, 'Blast_PCRM_R13-0057A': 1.0, 'Blast_PCRM_R13-0065A': 1.0, 'Blast_PCRM_R13-0065B': 1.0, 'Blast_PCRM_R13-0077A': 0.0, 'Blast_PCRM_R13-0077B': 0.0, 'Blast_PCRM_R13-0079A': 1.0, 'Blast_PCRM_R13-0079B': 1.0, 'Blast_PCRM_R13-0081A': 1.0, 'Blast_PCRM_R13-0081B': 1.0, 'Blast_PCRM_R13-0083': 1.0, 'Blast_PCRM_R13-0090': 0.0, 'Blast_PCRM_R13-0097': 1.0, 'Blast_PCRM_R13-0127': 1.0, 'Blast_PCRM_R13-0129b': 0.0, 'Blast_PCRM_R13-0131': 1.0, 'Blast_PCRM_R13-0140a': 1.0, 'Blast_PCRM_R13-0140b': 1.0, 'Blast_PCRM_R13-0145': 0.0, 'Blast_PCRM_R13-0163': 1.0, 'Blast_PCRM_R13-0167a': 1.0, 'Blast_PCRM_R13-0167b': 1.0, 'Blast_PCRM_R13-0218a': 0.0, 'Blast_PCRM_R13-0232': 1.0, 'Blast_PCRM_R13-0235a': 1.0, 'Blast_PCRM_R13-0235b': 1.0, 'Blast_PCRM_R13-0236a': 1.0, 'Blast_PCRM_R13-0236b': 1.0, 'Blast_PCRM_R13-0237b': 1.0, 'Blast_PCRM_R13-0261': 1.0, 'Blast_PCRM_R13-0298': 0.0, 'Blast_PCRM_R13-0309b': 1.0, 'Blast_PCRM_R13-0312': 1.0, 'Blast_PCRM_R13-0322b': 1.0, 'Blast_PCRM_R13-0325': 1.0, 'Blast_PCRM_R13-0348': 1.0, 'Blast_PCRM_R13-0351': 1.0, 'Blast_PCRM_R13-0383a': 1.0, 'Blast_PCRM_R13-0383b': 1.0, 'Blast_PCRM_R13-0385b': 1.0, 'Blast_PCRM_R13-0393': 1.0, 'Blast_PCRM_R13-0410a': 0.0, 'Blast_PCRM_R13-0410b': 0.0, 'Blast_PCRM_R13-0447a': 0.0, 'Blast_PCRM_R13-0459': 0.0, 'Blast_PCRM_R13-0494a': 0.0, 'Blast_PCRM_R13-0507a': 1.0, 'Blast_PCRM_R13-0524': 1.0, 'Blast_PCRM_R13-0564': 0.0, 'Blast_PCRM_R14-0033': 1.0, 'Blast_PCRM_R14-0044': 0.0, 'Blast_PCRM_R14-0068': 1.0, 'Blast_PCRM_R14-0069a': 1.0, 'Blast_PCRM_R14-0070': 1.0, 'Blast_PCRM_R14-0073': 0.0, 'Blast_PCRM_R14-0090': 1.0, 'Blast_PCRM_R14-0110': 1.0, 'Blast_PCRM_R14-0114': 0.0, 'Blast_PCRM_R14-0116': 1.0, 'Blast_PCRM_R14-0118': 0.0, 'Blast_PCRM_R14-0121': 1.0, 'Blast_PCRM_R14-0163': 1.0, 'Blast_PCRM_R14-0175': 1.0, 'Blast_PCRM_R14-0180': 0.0, 'Blast_PCRM_R14-0186': 0.0, 'Blast_PCRM_R14-0214': 0.0, 'Blast_PCRM_R14-0238': 1.0, 'Blast_PCRM_R14-0239': 1.0, 'Blast_PCRM_R14-0273': 0.0, 'Blast_PCRM_R14-0294': 0.0, 'Blast_PCRM_R14-0296': 0.0, 'Blast_PCRM_R14-0302': 1.0, 'Blast_PCRM_R14-0323': 1.0, 'Blast_PCRM_R14-0324a': 0.0, 'Blast_PCRM_R14-0324b': 0.0, 'Blast_PCRM_R14-0326b': 1.0, 'Blast_PCRM_R14-0327a': 0.0, 'Blast_PCRM_R14-0335a': 0.0, 'Blast_PCRM_R14-0348a': 1.0, 'Blast_PCRM_R14-0351': 0.0, 'Blast_PCRM_R14-0353a': 1.0, 'Blast_PCRM_R14-0354a': 1.0, 'Blast_PCRM_R14-0362a': 0.0, 'Blast_PCRM_R14-0362b': 0.0, 'Blast_PCRM_R14-0369a': 0.0, 'Blast_PCRM_R14-0370a': 0.0, 'Blast_PCRM_R14-0379': 0.0, 'Blast_PCRM_R14-0388a': 0.0, 'Blast_PCRM_R14-0392a': 0.0, 'Blast_PCRM_R14-0402b': 1.0, 'Blast_PCRM_R14-0404a': 1.0, 'Blast_PCRM_R14-0405b': 1.0, 'Blast_PCRM_R1 ...

# %%
""" Seeding """
np.random.seed(42)
tf.random.set_seed(42)

# %%
SIZE=256
def read_image_tf(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (SIZE, SIZE))
    x = x / 255.0
    return x.astype(np.float32)

def read_mask_tf(path):
    path = path.decode()
    y = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    y = cv2.resize(y, (SIZE, SIZE))
    y[y != 0] = 255
    y = y / 255.0
    y = (y > 0.5).astype(np.float32)
    y = np.expand_dims(y, axis=-1)
    return y

def read_multiclass_mask_tf(te_path, zp_path, icm_path):
    te = read_mask_tf(te_path)
    zp = read_mask_tf(zp_path)
    icm = read_mask_tf(icm_path)
    mask = np.concatenate([te, zp, icm], axis=-1)  # (H, W, 3)
    return mask

def tf_parse_multi_with_cls(x_path, te_path, zp_path, icm_path, cls_label):
    def _parse(x_path, te_path, zp_path, icm_path, cls_label):
        x = read_image_tf(x_path)
        y = read_multiclass_mask_tf(te_path, zp_path, icm_path)
        return x, y, cls_label

    x, y, cls_label = tf.numpy_function(
        _parse,
        [x_path, te_path, zp_path, icm_path, cls_label],
        [tf.float32, tf.float32, tf.float32]
    )
    x.set_shape([SIZE, SIZE, 3])
    y.set_shape([SIZE, SIZE, 3])  # 3 channels: TE, ZP, ICM
    cls_label.set_shape([])
    return x, (y, cls_label)

def tf_dataset_multi_with_cls(x_paths, te_paths, zp_paths, icm_paths, cls_labels, batch_size=16, shuffle=True):
  dataset = tf.data.Dataset.from_tensor_slices((x_paths, te_paths, zp_paths, icm_paths, cls_labels))
  if shuffle:
      dataset = dataset.shuffle(buffer_size=1000)
  dataset = dataset.map(tf_parse_multi_with_cls, num_parallel_calls=tf.data.AUTOTUNE)
  dataset = dataset.batch(batch_size)
  dataset = dataset.prefetch(tf.data.AUTOTUNE)
  return dataset

def filter_dataset_by_outcome(images, y1, y2, y3, image_to_outcome):
    filtered_x = []
    filtered_y1 = []
    filtered_y2 = []
    filtered_y3 = []
    filtered_labels = []

    for i, image_path in enumerate(images):
        outcome = get_outcome_from_path(image_path)
        if outcome in [0.0, 1.0]:
            filtered_x.append(image_path)
            filtered_y1.append(y1[i])
            filtered_y2.append(y2[i])
            filtered_y3.append(y3[i])
            filtered_labels.append(outcome)
    return filtered_x, filtered_y1, filtered_y2, filtered_y3, filtered_labels

# %% [markdown]
# *   Number of training images with outcome 0: 285
# *   Number of training images with outcome 1: 390
# *   Number of training images with outcome 2: 320

# %%
images = '/content/drive/MyDrive/PFA_Final/new_data/train/images'
temask = '/content/drive/MyDrive/PFA_Final/new_data/train/GT_TE'
zpmask = '/content/drive/MyDrive/PFA_Final/new_data/train/GT_ZP'
icmmask = '/content/drive/MyDrive/PFA_Final/new_data/train/GT_ICM'

images_test = '/content/drive/MyDrive/PFA_Final/new_data/test/images'
temask_test = '/content/drive/MyDrive/PFA_Final/new_data/test/GT_TE'
zpmask_test = '/content/drive/MyDrive/PFA_Final/new_data/test/GT_ZP'
icmmask_test = '/content/drive/MyDrive/PFA_Final/new_data/test/GT_ICM'

images_valid = '/content/drive/MyDrive/PFA_Final/new_data/valid/images'
temask_valid = '/content/drive/MyDrive/PFA_Final/new_data/valid/GT_TE'
zpmask_valid = '/content/drive/MyDrive/PFA_Final/new_data/valid/GT_ZP'
icmmask_valid = '/content/drive/MyDrive/PFA_Final/new_data/valid/GT_ICM'

train_x = sorted(glob(os.path.join(images, "*.bmp")))
train_y1 = sorted(glob(os.path.join(temask, "*.bmp")))
train_y2 = sorted(glob(os.path.join(zpmask, "*.bmp")))
train_y3 = sorted(glob(os.path.join(icmmask, "*.bmp")))

test_x = sorted(glob(os.path.join(images_test, "*.bmp")))
test_y1 = sorted(glob(os.path.join(temask_test, "*.bmp")))
test_y2 = sorted(glob(os.path.join(zpmask_test, "*.bmp")))
test_y3 = sorted(glob(os.path.join(icmmask_test, "*.bmp")))

valid_x = sorted(glob(os.path.join(images_valid, "*.bmp")))
valid_y1 = sorted(glob(os.path.join(temask_valid, "*.bmp")))
valid_y2 = sorted(glob(os.path.join(zpmask_valid, "*.bmp")))
valid_y3 = sorted(glob(os.path.join(icmmask_valid, "*.bmp")))

# %%
filtered_train_x,filtered_train_y1,filtered_train_y2,filtered_train_y3,filtered_train_labels = filter_dataset_by_outcome(
    train_x, train_y1, train_y2, train_y3, image_to_outcome)

print("Training data:", Counter(filtered_train_labels))

# Undersample majority class (1)
indices_by_class = defaultdict(list)
for idx, label in enumerate(filtered_train_labels):
    indices_by_class[label].append(idx)

minority_class_size = min(len(indices_by_class[0]), len(indices_by_class[1]))
undersampled_indices = indices_by_class[0] + random.sample(indices_by_class[1], minority_class_size)
random.shuffle(undersampled_indices)

undersampled_train_x = [filtered_train_x[i] for i in undersampled_indices]
undersampled_train_y1 = [filtered_train_y1[i] for i in undersampled_indices]
undersampled_train_y2 = [filtered_train_y2[i] for i in undersampled_indices]
undersampled_train_y3 = [filtered_train_y3[i] for i in undersampled_indices]
undersampled_train_labels = [filtered_train_labels[i] for i in undersampled_indices]
print("After undersampling:", Counter(undersampled_train_labels))

train_ds = tf_dataset_multi_with_cls(
    undersampled_train_x,
    undersampled_train_y1,
    undersampled_train_y2,
    undersampled_train_y3,
    undersampled_train_labels,
    batch_size=8,
)
# Out:
# Training data: Counter({1.0: 390, 0.0: 285})
# After undersampling: Counter({0.0: 285, 1.0: 285})

# %%
# Validation data
valid_filtered_x, valid_filtered_y1, valid_filtered_y2, valid_filtered_y3, valid_filtered_labels = filter_dataset_by_outcome(
    valid_x, valid_y1, valid_y2, valid_y3, image_to_outcome)

valid_ds = tf_dataset_multi_with_cls(
    valid_filtered_x,
    valid_filtered_y1,
    valid_filtered_y2,
    valid_filtered_y3,
    valid_filtered_labels,
    batch_size=8,
    shuffle=False
)

# Test data
test_filtered_x, test_filtered_y1, test_filtered_y2, test_filtered_y3, test_filtered_labels = filter_dataset_by_outcome(
    test_x, test_y1, test_y2, test_y3, image_to_outcome)

test_ds = tf_dataset_multi_with_cls(
    test_filtered_x,
    test_filtered_y1,
    test_filtered_y2,
    test_filtered_y3,
    test_filtered_labels,
    batch_size=8,
    shuffle=False
)
print(test_ds.take(1))
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), (TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None)))>

# %%
smooth = 1e-15

cls_callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_classification_loss',
        factor=0.5,       # halve LR (less aggressive than 0.3, more stable)
        patience=3,       # classification is stalling quickly, so react faster
        min_lr=5e-6,
        mode='min',
        verbose=1
    )
]


seg_callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_segmentation_loss',
        factor=0.1,
        patience=10,
        min_lr=5e-6,
        mode='min',
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_segmentation_loss',
        patience=50,
        restore_best_weights=True,
        mode='min'
    )
]

def iou_multiclass(y_true, y_pred):
    y_true = tf.round(y_true)
    y_pred = tf.round(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[0,1,2])  # sum per channel
    union = tf.reduce_sum(y_true, axis=[0,1,2]) + tf.reduce_sum(y_pred, axis=[0,1,2]) - intersection
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

def dice_coef_multiclass(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred, axis=[0,1,2])
    denominator = tf.reduce_sum(y_true, axis=[0,1,2]) + tf.reduce_sum(y_pred, axis=[0,1,2])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef_multiclass(y_true, y_pred)

# %%
weight_decay=1e-8

def conv_block(x, filters, dropout=False):
    x = layers.Conv2D(filters, (3, 3), padding="same", kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(filters, (3, 3), padding="same", kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    if dropout:
        x = layers.Dropout(0.5)(x)

    return x

def encoder_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPooling2D((2, 2))(c)
    return c, p

def decoder_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x

# %%
def classification_head_v1(bottleneck_feat):
  gap = layers.GlobalAveragePooling1D()(bottleneck_feat)
  x = layers.Dense(128, activation='relu')(gap)
  x = layers.Dropout(0.4)(x)
  return layers.Dense(1, activation='sigmoid', name="classification")(x)

def classification_head_v2(bottleneck_feat, dropout_rate=0.3, l2_reg=1e-4):
    x = layers.GlobalAveragePooling2D()(bottleneck_feat)
    x = layers.Dense(128, activation='relu',
                     kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.Dropout(dropout_rate)(x)
    output = layers.Dense(1, activation='sigmoid', name="classification")(x)
    return output

def cls_head_midfeature(mid_feat):
    x = layers.GlobalAveragePooling2D()(mid_feat)
    x = layers.LayerNormalization()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    cls_output = layers.Dense(1, activation='sigmoid', name='classification')(x)
    return cls_output

def classification_head_combined(mid_feat, bottleneck_feat, dropout_rate=0.5, l2_reg=1e-4):
    mid_pool = layers.GlobalAveragePooling2D()(mid_feat)
    b1_reshaped = layers.Reshape((-1, bottleneck_feat.shape[-1]))(bottleneck_feat)  # (B, N_patches, D)
    bottleneck_pool = layers.GlobalAveragePooling1D()(b1_reshaped)  # shape -> (B, D)

    x = layers.Concatenate()([mid_pool, bottleneck_pool])  # shape -> (B, C_mid + D)

    x = layers.Dense(128, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(64, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.Dropout(dropout_rate)(x)

    return layers.Dense(1, activation='sigmoid', name="classification")(x)

# %%
# image sequentialization: shaping the input x into a sequence of flattened 2D patches
def patch_embedding(x, patch_size, embed_dim):
    x = layers.Conv2D(embed_dim, kernel_size=patch_size, strides=patch_size, padding='valid')(x)
    # (B, H/P, W/P, D=embed_dim), reshaped to (B, N, D), N=H*W/P²
    x = layers.Reshape((-1, embed_dim))(x)
    return x

def transformer_block(x, embed_dim, num_heads, mlp_dim, dropout=0.1, return_attention=False):
    norm1 = layers.LayerNormalization(epsilon=1e-6)(x)
    mha = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim, dropout=dropout)

    if return_attention:
        attn_output, attn_scores = mha(norm1, norm1, return_attention_scores=True)
    else:
        attn_output = mha(norm1, norm1)

    x = layers.Add()([x, attn_output])

    norm2 = layers.LayerNormalization(epsilon=1e-6)(x)
    mlp_output = layers.Dense(mlp_dim, activation='gelu')(norm2)
    mlp_output = layers.Dropout(dropout)(mlp_output)
    mlp_output = layers.Dense(embed_dim)(mlp_output)
    mlp_output = layers.Dropout(dropout)(mlp_output)
    x = layers.Add()([x, mlp_output])

    if return_attention:
        return x, attn_scores
    return x

def transformer_bottleneck(x, patch_size=1, num_layers=4, embed_dim=512, num_heads=8, mlp_dim=1024, return_all_attention=False):
    h, w, c = x.shape[1:]

    # Image Sequentialization.
    x = patch_embedding(x, patch_size, embed_dim)  # (B, N, D)

    # Positional encoding
    pos_emb = tf.Variable(tf.random.normal([1, x.shape[1], embed_dim]), trainable=True)
    x = x + pos_emb # Patch Embedding.

    attn_maps = []  # attention scores
    for _ in range(num_layers):
        if return_all_attention:
            x, attn = transformer_block(x, embed_dim, num_heads, mlp_dim, return_attention=True)
            attn_maps.append(attn)
        else:
            x = transformer_block(x, embed_dim, num_heads, mlp_dim)

    # Reshape back to 2D
    new_h, new_w = h // patch_size, w // patch_size
    x = layers.Reshape((new_h, new_w, embed_dim))(x)

    if return_all_attention:
        return x, attn_maps
    return x

def build_transunet(input_shape, return_attention=False):
    inputs = tf.keras.Input(input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4 = conv_block(p3, 512, dropout=True)
    p4 = layers.MaxPooling2D((2, 2))(s4)

    # Transformer bottleneck
    if return_attention:
        b1, attention_maps = transformer_bottleneck(p4, patch_size=1, num_layers=4,
                                                    embed_dim=512, num_heads=8,
                                                    mlp_dim=1024, return_all_attention=True)
    else:
        b1 = transformer_bottleneck(p4, patch_size=1, num_layers=4,
                                    embed_dim=512, num_heads=8,
                                    mlp_dim=1024, return_all_attention=False)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    seg_output = layers.Conv2D(3, 1, padding="same", activation="sigmoid", name="segmentation")(d4)
    cls_output = classification_head_combined(p3, b1)

    if return_attention:
        return Model(inputs, [seg_output, cls_output, attention_maps])
    return Model(inputs, [seg_output, cls_output])

# %%
X = np.array(undersampled_train_x)
y1 = np.array(undersampled_train_y1)
y2 = np.array(undersampled_train_y2)
y3 = np.array(undersampled_train_y3)
y_cls = np.array(undersampled_train_labels).astype(np.float32) # Cast to float32 here

kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_no = 1
val_scores = []

for train_idx, val_idx in kf.split(X):
    print(f"\n--- Fold {fold_no} ---")

    train_ds_fold = tf_dataset_multi_with_cls(
        X[train_idx], y1[train_idx], y2[train_idx], y3[train_idx], y_cls[train_idx],
        batch_size=8, shuffle=True
    )

    val_ds_fold = tf_dataset_multi_with_cls(
        X[val_idx], y1[val_idx], y2[val_idx], y3[val_idx], y_cls[val_idx],
        batch_size=8, shuffle=False
    )

    model = build_transunet(input_shape=(SIZE, SIZE, 3), return_attention=False)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss={
            "segmentation": dice_loss,
            "classification": tf.keras.losses.BinaryCrossentropy(from_logits=False)
        },
        loss_weights={"segmentation": 1.0, "classification": 2.5},  # adjust if needed
        metrics={
            "segmentation": [dice_coef_multiclass, iou_multiclass],
            "classification": [
                tf.keras.metrics.AUC(name="auprc", curve="PR"),
                tf.keras.metrics.Precision(name="precision"),
                tf.keras.metrics.Recall(name="recall"),
                tf.keras.metrics.BinaryAccuracy(name="accuracy")
            ]
        }
    )

    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=8, min_lr=1e-7, verbose=1
    )
    early_stop = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss", patience=25, restore_best_weights=True, verbose=1
    )

    history = model.fit(
        train_ds_fold,
        validation_data=val_ds_fold,
        epochs=200,
        callbacks=[reduce_lr, early_stop],
        verbose=1
    )

    scores = model.evaluate(val_ds_fold, verbose=0)
    print(f"Fold {fold_no} scores: {scores}")
    val_scores.append(scores)

    fold_no += 1

val_scores = np.array(val_scores)
print("\n=== 5-Fold Cross-Validation Results ===")
print("Mean:", val_scores.mean(axis=0))
print("Std:", val_scores.std(axis=0))
# Out:
# --- Fold 1 ---
# Epoch 1/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 633s 10s/step - classification_accuracy: 0.5329 - classification_auprc: 0.5640 - classification_loss: 0.8022 - classification_precision: 0.5237 - classification_recall: 0.6324 - loss: 2.7742 - segmentation_dice_coef_multiclass: 0.2618 - segmentation_iou_multiclass: 0.1832 - segmentation_loss: 0.7382 - val_classification_accuracy: 0.4474 - val_classification_auprc: 0.5322 - val_classification_loss: 0.8187 - val_classification_precision: 0.4474 - val_classification_recall: 1.0000 - val_loss: 2.8653 - val_segmentation_dice_coef_multiclass: 0.2607 - val_segmentation_iou_multiclass: 0.2232 - val_segmentation_loss: 0.7393 - learning_rate: 1.0000e-04
# Epoch 2/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 36s 634ms/step - classification_accuracy: 0.5538 - classification_auprc: 0.5270 - classification_loss: 0.8346 - classification_precision: 0.5293 - classification_recall: 0.6411 - loss: 2.6717 - segmentation_dice_coef_multiclass: 0.4453 - segmentation_iou_multiclass: 0.3802 - segmentation_loss: 0.5547 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6275 - val_classification_loss: 0.6621 - val_classification_precision: 0.6111 - val_classification_recall: 0.6471 - val_loss: 2.4041 - val_segmentation_dice_coef_multiclass: 0.2699 - val_segmentation_iou_multiclass: 0.1873 - val_segmentation_loss: 0.7301 - learning_rate: 1.0000e-04
# Epoch 3/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 650ms/step - classification_accuracy: 0.5328 - classification_auprc: 0.5228 - classification_loss: 0.8739 - classification_precision: 0.5359 - classification_recall: 0.6082 - loss: 2.7175 - segmentation_dice_coef_multiclass: 0.4976 - segmentation_iou_multiclass: 0.4481 - segmentation_loss: 0.5024 - val_classification_accuracy: 0.5702 - val_classification_auprc: 0.4638 - val_classification_loss: 0.6768 - val_classification_precision: 0.5132 - val_classification_recall: 0.7647 - val_loss: 2.3496 - val_segmentation_dice_coef_multiclass: 0.3778 - val_segmentation_iou_multiclass: 0.3115 - val_segmentation_loss: 0.6222 - learning_rate: 1.0000e-04
# Epoch 4/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 671ms/step - classification_accuracy: 0.5553 - classification_auprc: 0.5356 - classification_loss: 0.7726 - classification_precision: 0.5295 - classification_recall: 0.6361 - loss: 2.4094 - segmentation_dice_coef_multiclass: 0.5523 - segmentation_iou_multiclass: 0.5317 - segmentation_loss: 0.4477 - val_classification_accuracy: 0.5526 - val_classification_auprc: 0.4499 - val_classification_loss: 0.7140 - val_classification_precision: 0.0000e+00 - val_classification_recall: 0.0000e+00 - val_loss: 2.3724 - val_segmentation_dice_coef_multiclass: 0.4130 - val_segmentation_iou_multiclass: 0.3266 - val_segmentation_loss: 0.5870 - learning_rate: 1.0000e-04
# Epoch 5/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 678ms/step - classification_accuracy: 0.5945 - classification_auprc: 0.6064 - classification_loss: 0.7259 - classification_precision: 0.5894 - classification_recall: 0.6380 - loss: 2.2665 - segmentation_dice_coef_multiclass: 0.5787 - segmentation_iou_multiclass: 0.5447 - segmentation_loss: 0.4213 - val_classification_accuracy: 0.5614 - val_classification_auprc: 0.5941 - val_classification_loss: 0.6810 - val_classification_precision: 1.0000 - val_classification_recall: 0.0196 - val_loss: 2.3246 - val_segmentation_dice_coef_multiclass: 0.3904 - val_segmentation_iou_multiclass: 0.3022 - val_segmentation_loss: 0.6096 - learning_rate: 1.0000e-04
# Epoch 6/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 718ms/step - classification_accuracy: 0.5333 - classification_auprc: 0.5408 - classification_loss: 0.8435 - classification_precision: 0.5437 - classification_recall: 0.6365 - loss: 2.5343 - segmentation_dice_coef_multiclass: 0.6047 - segmentation_iou_multiclass: 0.5653 - segmentation_loss: 0.3953 - val_classification_accuracy: 0.5702 - val_classification_auprc: 0.5727 - val_classification_loss: 0.6956 - val_classification_precision: 1.0000 - val_classification_recall: 0.0392 - val_loss: 2.2530 - val_segmentation_dice_coef_multiclass: 0.4905 - val_segmentation_iou_multiclass: 0.4096 - val_segmentation_loss: 0.5095 - learning_rate: 1.0000e-04
# Epoch 7/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 79s 660ms/step - classification_accuracy: 0.5052 - classification_auprc: 0.5124 - classification_loss: 0.8061 - classification_precision: 0.4844 - classification_recall: 0.5618 - loss: 2.4174 - segmentation_dice_coef_multiclass: 0.6281 - segmentation_iou_multiclass: 0.5832 - segmentation_loss: 0.3719 - val_classification_accuracy: 0.4912 - val_classification_auprc: 0.6259 - val_classification_loss: 0.7481 - val_classification_precision: 0.4568 - val_classification_recall: 0.7255 - val_loss: 2.3941 - val_segmentation_dice_coef_multiclass: 0.5745 - val_segmentation_iou_multiclass: 0.4852 - val_segmentation_loss: 0.4255 - learning_rate: 1.0000e-04
# Epoch 8/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 675ms/step - classification_accuracy: 0.4543 - classification_auprc: 0.5503 - classification_loss: 0.8098 - classification_precision: 0.4772 - classification_recall: 0.4856 - loss: 2.4205 - segmentation_dice_coef_multiclass: 0.6343 - segmentation_iou_multiclass: 0.5779 - segmentation_loss: 0.3657 - val_classification_accuracy: 0.4649 - val_classification_auprc: 0.5888 - val_classification_loss: 0.7843 - val_classification_precision: 0.4419 - val_classification_recall: 0.7451 - val_loss: 2.4395 - val_segmentation_dice_coef_multiclass: 0.6228 - val_segmentation_iou_multiclass: 0.5512 - val_segmentation_loss: 0.3772 - learning_rate: 1.0000e-04
# Epoch 9/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 688ms/step - classification_accuracy: 0.5423 - classification_auprc: 0.5321 - classification_loss: 0.7944 - classification_precision: 0.5489 - classification_recall: 0.5783 - loss: 2.3501 - segmentation_dice_coef_multiclass: 0.6664 - segmentation_iou_multiclass: 0.6203 - segmentation_loss: 0.3336 - val_classification_accuracy: 0.5877 - val_classification_auprc: 0.6662 - val_classification_loss: 0.6471 - val_classification_precision: 0.5227 - val_classification_recall: 0.9020 - val_loss: 1.9996 - val_segmentation_dice_coef_multiclass: 0.6902 - val_segmentation_iou_multiclass: 0.6326 - val_segmentation_loss: 0.3098 - learning_rate: 1.0000e-04
# Epoch 10/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 724ms/step - classification_accuracy: 0.5688 - classification_auprc: 0.5893 - classification_loss: 0.7590 - classification_precision: 0.5818 - classification_recall: 0.6181 - loss: 2.2366 - segmentation_dice_coef_multiclass: 0.6912 - segmentation_iou_multiclass: 0.6506 - segmentation_loss: 0.3088 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.7037 - val_classification_loss: 0.6335 - val_classification_precision: 0.6579 - val_classification_recall: 0.4902 - val_loss: 1.9514 - val_segmentation_dice_coef_multiclass: 0.6526 - val_segmentation_iou_multiclass: 0.5914 - val_segmentation_loss: 0.3474 - learning_rate: 1.0000e-04
# Epoch 11/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 702ms/step - classification_accuracy: 0.5480 - classification_auprc: 0.5915 - classification_loss: 0.7814 - classification_precision: 0.5429 - classification_recall: 0.6070 - loss: 2.2756 - segmentation_dice_coef_multiclass: 0.7082 - segmentation_iou_multiclass: 0.6581 - segmentation_loss: 0.2918 - val_classification_accuracy: 0.5439 - val_classification_auprc: 0.6915 - val_classification_loss: 0.7068 - val_classification_precision: 0.4947 - val_classification_recall: 0.9216 - val_loss: 2.2169 - val_segmentation_dice_coef_multiclass: 0.6471 - val_segmentation_iou_multiclass: 0.5678 - val_segmentation_loss: 0.3529 - learning_rate: 1.0000e-04
# Epoch 12/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 712ms/step - classification_accuracy: 0.5303 - classification_auprc: 0.5876 - classification_loss: 0.7901 - classification_precision: 0.5618 - classification_recall: 0.5661 - loss: 2.2976 - segmentation_dice_coef_multiclass: 0.7079 - segmentation_iou_multiclass: 0.6399 - segmentation_loss: 0.2921 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.6213 - val_classification_loss: 0.6572 - val_classification_precision: 0.5507 - val_classification_recall: 0.7451 - val_loss: 1.9880 - val_segmentation_dice_coef_multiclass: 0.7047 - val_segmentation_iou_multiclass: 0.6361 - val_segmentation_loss: 0.2953 - learning_rate: 1.0000e-04
# Epoch 13/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 716ms/step - classification_accuracy: 0.5703 - classification_auprc: 0.5680 - classification_loss: 0.8040 - classification_precision: 0.5781 - classification_recall: 0.5472 - loss: 2.3315 - segmentation_dice_coef_multiclass: 0.7088 - segmentation_iou_multiclass: 0.6325 - segmentation_loss: 0.2912 - val_classification_accuracy: 0.5789 - val_classification_auprc: 0.5933 - val_classification_loss: 0.6883 - val_classification_precision: 0.5165 - val_classification_recall: 0.9216 - val_loss: 2.2680 - val_segmentation_dice_coef_multiclass: 0.5313 - val_segmentation_iou_multiclass: 0.4194 - val_segmentation_loss: 0.4687 - learning_rate: 1.0000e-04
# Epoch 14/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 695ms/step - classification_accuracy: 0.5364 - classification_auprc: 0.6062 - classification_loss: 0.7399 - classification_precision: 0.5684 - classification_recall: 0.5696 - loss: 2.1631 - segmentation_dice_coef_multiclass: 0.7169 - segmentation_iou_multiclass: 0.6340 - segmentation_loss: 0.2831 - val_classification_accuracy: 0.5000 - val_classification_auprc: 0.5721 - val_classification_loss: 0.6995 - val_classification_precision: 0.4643 - val_classification_recall: 0.7647 - val_loss: 2.2211 - val_segmentation_dice_coef_multiclass: 0.6093 - val_segmentation_iou_multiclass: 0.5104 - val_segmentation_loss: 0.3907 - learning_rate: 1.0000e-04
# Epoch 15/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 733ms/step - classification_accuracy: 0.5418 - classification_auprc: 0.5897 - classification_loss: 0.7749 - classification_precision: 0.5751 - classification_recall: 0.5819 - loss: 2.2510 - segmentation_dice_coef_multiclass: 0.7166 - segmentation_iou_multiclass: 0.6298 - segmentation_loss: 0.2834 - val_classification_accuracy: 0.5175 - val_classification_auprc: 0.5805 - val_classification_loss: 0.6719 - val_classification_precision: 0.4706 - val_classification_recall: 0.6275 - val_loss: 2.2685 - val_segmentation_dice_coef_multiclass: 0.4776 - val_segmentation_iou_multiclass: 0.3491 - val_segmentation_loss: 0.5224 - learning_rate: 1.0000e-04
# Epoch 16/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 78s 668ms/step - classification_accuracy: 0.5204 - classification_auprc: 0.5629 - classification_loss: 0.7941 - classification_precision: 0.5436 - classification_recall: 0.5616 - loss: 2.2745 - segmentation_dice_coef_multiclass: 0.7410 - segmentation_iou_multiclass: 0.6541 - segmentation_loss: 0.2590 - val_classification_accuracy: 0.6491 - val_classification_auprc: 0.6197 - val_classification_loss: 0.6658 - val_classification_precision: 0.6341 - val_classification_recall: 0.5098 - val_loss: 2.2213 - val_segmentation_dice_coef_multiclass: 0.4792 - val_segmentation_iou_multiclass: 0.3421 - val_segmentation_loss: 0.5208 - learning_rate: 1.0000e-04
# Epoch 17/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 710ms/step - classification_accuracy: 0.5136 - classification_auprc: 0.5190 - classification_loss: 0.7932 - classification_precision: 0.4997 - classification_recall: 0.5179 - loss: 2.3332 - segmentation_dice_coef_multiclass: 0.6802 - segmentation_iou_multiclass: 0.5658 - segmentation_loss: 0.3198 - val_classification_accuracy: 0.4561 - val_classification_auprc: 0.4901 - val_classification_loss: 0.7174 - val_classification_precision: 0.4321 - val_classification_recall: 0.6863 - val_loss: 2.2057 - val_segmentation_dice_coef_multiclass: 0.6262 - val_segmentation_iou_multiclass: 0.5089 - val_segmentation_loss: 0.3738 - learning_rate: 1.0000e-04
# Epoch 18/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - classification_accuracy: 0.5101 - classification_auprc: 0.5776 - classification_loss: 0.7801 - classification_precision: 0.5281 - classification_recall: 0.5495 - loss: 2.2598 - segmentation_dice_coef_multiclass: 0.7208 - segmentation_iou_multiclass: 0.6151 - segmentation_loss: 0.2792
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 686ms/step - classification_accuracy: 0.5099 - classification_auprc: 0.5769 - classification_loss: 0.7805 - classification_precision: 0.5278 - classification_recall: 0.5490 - loss: 2.2608 - segmentation_dice_coef_multiclass: 0.7209 - segmentation_iou_multiclass: 0.6151 - segmentation_loss: 0.2791 - val_classification_accuracy: 0.5526 - val_classification_auprc: 0.5602 - val_classification_loss: 0.6777 - val_classification_precision: 0.5000 - val_classification_recall: 0.4118 - val_loss: 2.0645 - val_segmentation_dice_coef_multiclass: 0.6582 - val_segmentation_iou_multiclass: 0.5446 - val_segmentation_loss: 0.3418 - learning_rate: 1.0000e-04
# Epoch 19/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 689ms/step - classification_accuracy: 0.4825 - classification_auprc: 0.5561 - classification_loss: 0.8460 - classification_precision: 0.5126 - classification_recall: 0.5442 - loss: 2.3999 - segmentation_dice_coef_multiclass: 0.7454 - segmentation_iou_multiclass: 0.6451 - segmentation_loss: 0.2546 - val_classification_accuracy: 0.5965 - val_classification_auprc: 0.6024 - val_classification_loss: 0.6740 - val_classification_precision: 0.5532 - val_classification_recall: 0.5098 - val_loss: 1.9641 - val_segmentation_dice_coef_multiclass: 0.7257 - val_segmentation_iou_multiclass: 0.6257 - val_segmentation_loss: 0.2743 - learning_rate: 5.0000e-05
# Epoch 20/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 696ms/step - classification_accuracy: 0.4660 - classification_auprc: 0.4969 - classification_loss: 0.8434 - classification_precision: 0.4622 - classification_recall: 0.5177 - loss: 2.3768 - segmentation_dice_coef_multiclass: 0.7620 - segmentation_iou_multiclass: 0.6671 - segmentation_loss: 0.2380 - val_classification_accuracy: 0.5965 - val_classification_auprc: 0.6265 - val_classification_loss: 0.6690 - val_classification_precision: 0.5926 - val_classification_recall: 0.3137 - val_loss: 1.9889 - val_segmentation_dice_coef_multiclass: 0.6975 - val_segmentation_iou_multiclass: 0.5902 - val_segmentation_loss: 0.3025 - learning_rate: 5.0000e-05
# Epoch 21/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 734ms/step - classification_accuracy: 0.5668 - classification_auprc: 0.6305 - classification_loss: 0.7096 - classification_precision: 0.6132 - classification_recall: 0.5666 - loss: 2.0364 - segmentation_dice_coef_multiclass: 0.7678 - segmentation_iou_multiclass: 0.6717 - segmentation_loss: 0.2322 - val_classification_accuracy: 0.5614 - val_classification_auprc: 0.5508 - val_classification_loss: 0.6851 - val_classification_precision: 1.0000 - val_classification_recall: 0.0196 - val_loss: 1.9858 - val_segmentation_dice_coef_multiclass: 0.7397 - val_segmentation_iou_multiclass: 0.6396 - val_segmentation_loss: 0.2603 - learning_rate: 5.0000e-05
# Epoch 22/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 80s 706ms/step - classification_accuracy: 0.5656 - classification_auprc: 0.6182 - classification_loss: 0.7154 - classification_precision: 0.5717 - classification_recall: 0.5805 - loss: 2.0560 - segmentation_dice_coef_multiclass: 0.7627 - segmentation_iou_multiclass: 0.6631 - segmentation_loss: 0.2373 - val_classification_accuracy: 0.5789 - val_classification_auprc: 0.5468 - val_classification_loss: 0.6908 - val_classification_precision: 0.5385 - val_classification_recall: 0.4118 - val_loss: 2.1886 - val_segmentation_dice_coef_multiclass: 0.5722 - val_segmentation_iou_multiclass: 0.4517 - val_segmentation_loss: 0.4278 - learning_rate: 5.0000e-05
# Epoch 23/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 39s 676ms/step - classification_accuracy: 0.4914 - classification_auprc: 0.5423 - classification_loss: 0.8006 - classification_precision: 0.5203 - classification_recall: 0.5473 - loss: 2.2920 - segmentation_dice_coef_multiclass: 0.7397 - segmentation_iou_multiclass: 0.6306 - segmentation_loss: 0.2603 - val_classification_accuracy: 0.4211 - val_classification_auprc: 0.4005 - val_classification_loss: 0.7079 - val_classification_precision: 0.4051 - val_classification_recall: 0.6275 - val_loss: 2.1404 - val_segmentation_dice_coef_multiclass: 0.6733 - val_segmentation_iou_multiclass: 0.5496 - val_segmentation_loss: 0.3267 - learning_rate: 5.0000e-05
# Epoch 24/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 685ms/step - classification_accuracy: 0.5519 - classification_auprc: 0.5887 - classification_loss: 0.7749 - classification_precision: 0.6077 - classification_recall: 0.5505 - loss: 2.2092 - segmentation_dice_coef_multiclass: 0.7583 - segmentation_iou_multiclass: 0.6535 - segmentation_loss: 0.2417 - val_classification_accuracy: 0.5614 - val_classification_auprc: 0.6203 - val_classification_loss: 0.6709 - val_classification_precision: 0.5072 - val_classification_recall: 0.6863 - val_loss: 1.9624 - val_segmentation_dice_coef_multiclass: 0.7413 - val_segmentation_iou_multiclass: 0.6300 - val_segmentation_loss: 0.2587 - learning_rate: 5.0000e-05
# Epoch 25/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 730ms/step - classification_accuracy: 0.4810 - classification_auprc: 0.5519 - classification_loss: 0.8038 - classification_precision: 0.5033 - classification_recall: 0.4736 - loss: 2.2715 - segmentation_dice_coef_multiclass: 0.7683 - segmentation_iou_multiclass: 0.6659 - segmentation_loss: 0.2317 - val_classification_accuracy: 0.5351 - val_classification_auprc: 0.5887 - val_classification_loss: 0.6703 - val_classification_precision: 0.4844 - val_classification_recall: 0.6078 - val_loss: 1.9547 - val_segmentation_dice_coef_multiclass: 0.7387 - val_segmentation_iou_multiclass: 0.6296 - val_segmentation_loss: 0.2613 - learning_rate: 5.0000e-05
# Epoch 26/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - classification_accuracy: 0.4865 - classification_auprc: 0.5170 - classification_loss: 0.8111 - classification_precision: 0.4858 - classification_recall: 0.4672 - loss: 2.2800 - segmentation_dice_coef_multiclass: 0.7781 - segmentation_iou_multiclass: 0.6788 - segmentation_loss: 0.2219
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 79s 673ms/step - classification_accuracy: 0.4869 - classification_auprc: 0.5175 - classification_loss: 0.8106 - classification_precision: 0.4865 - classification_recall: 0.4682 - loss: 2.2788 - segmentation_dice_coef_multiclass: 0.7780 - segmentation_iou_multiclass: 0.6786 - segmentation_loss: 0.2220 - val_classification_accuracy: 0.6053 - val_classification_auprc: 0.5610 - val_classification_loss: 0.7573 - val_classification_precision: 0.5405 - val_classification_recall: 0.7843 - val_loss: 2.4249 - val_segmentation_dice_coef_multiclass: 0.5670 - val_segmentation_iou_multiclass: 0.4276 - val_segmentation_loss: 0.4330 - learning_rate: 5.0000e-05
# Epoch 27/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 676ms/step - classification_accuracy: 0.5019 - classification_auprc: 0.5313 - classification_loss: 0.8088 - classification_precision: 0.5145 - classification_recall: 0.5583 - loss: 2.2744 - segmentation_dice_coef_multiclass: 0.7779 - segmentation_iou_multiclass: 0.6752 - segmentation_loss: 0.2221 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6180 - val_classification_loss: 0.6732 - val_classification_precision: 0.5857 - val_classification_recall: 0.8039 - val_loss: 2.1092 - val_segmentation_dice_coef_multiclass: 0.6325 - val_segmentation_iou_multiclass: 0.5025 - val_segmentation_loss: 0.3675 - learning_rate: 2.5000e-05
# Epoch 28/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 687ms/step - classification_accuracy: 0.5088 - classification_auprc: 0.5752 - classification_loss: 0.7553 - classification_precision: 0.4944 - classification_recall: 0.5105 - loss: 2.1326 - segmentation_dice_coef_multiclass: 0.7859 - segmentation_iou_multiclass: 0.6875 - segmentation_loss: 0.2141 - val_classification_accuracy: 0.6316 - val_classification_auprc: 0.5972 - val_classification_loss: 0.6600 - val_classification_precision: 0.5918 - val_classification_recall: 0.5686 - val_loss: 1.9228 - val_segmentation_dice_coef_multiclass: 0.7598 - val_segmentation_iou_multiclass: 0.6518 - val_segmentation_loss: 0.2402 - learning_rate: 2.5000e-05
# Epoch 29/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 696ms/step - classification_accuracy: 0.5211 - classification_auprc: 0.5567 - classification_loss: 0.7787 - classification_precision: 0.5250 - classification_recall: 0.5025 - loss: 2.1906 - segmentation_dice_coef_multiclass: 0.7865 - segmentation_iou_multiclass: 0.6871 - segmentation_loss: 0.2135 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6368 - val_classification_loss: 0.6461 - val_classification_precision: 0.6579 - val_classification_recall: 0.4902 - val_loss: 1.8951 - val_segmentation_dice_coef_multiclass: 0.7380 - val_segmentation_iou_multiclass: 0.6210 - val_segmentation_loss: 0.2620 - learning_rate: 2.5000e-05
# Epoch 30/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 702ms/step - classification_accuracy: 0.5746 - classification_auprc: 0.5718 - classification_loss: 0.7592 - classification_precision: 0.5536 - classification_recall: 0.6537 - loss: 2.1389 - segmentation_dice_coef_multiclass: 0.7894 - segmentation_iou_multiclass: 0.6918 - segmentation_loss: 0.2106 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6468 - val_classification_loss: 0.6431 - val_classification_precision: 0.7143 - val_classification_recall: 0.3922 - val_loss: 1.8462 - val_segmentation_dice_coef_multiclass: 0.7754 - val_segmentation_iou_multiclass: 0.6699 - val_segmentation_loss: 0.2246 - learning_rate: 2.5000e-05
# Epoch 31/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 699ms/step - classification_accuracy: 0.5206 - classification_auprc: 0.5093 - classification_loss: 0.8063 - classification_precision: 0.5080 - classification_recall: 0.5744 - loss: 2.2594 - segmentation_dice_coef_multiclass: 0.7866 - segmentation_iou_multiclass: 0.6856 - segmentation_loss: 0.2134 - val_classification_accuracy: 0.6754 - val_classification_auprc: 0.6775 - val_classification_loss: 0.6330 - val_classification_precision: 0.7500 - val_classification_recall: 0.4118 - val_loss: 1.8038 - val_segmentation_dice_coef_multiclass: 0.7878 - val_segmentation_iou_multiclass: 0.6871 - val_segmentation_loss: 0.2122 - learning_rate: 2.5000e-05
# Epoch 32/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 698ms/step - classification_accuracy: 0.5774 - classification_auprc: 0.5841 - classification_loss: 0.7292 - classification_precision: 0.5610 - classification_recall: 0.6344 - loss: 2.0593 - segmentation_dice_coef_multiclass: 0.7940 - segmentation_iou_multiclass: 0.6953 - segmentation_loss: 0.2060 - val_classification_accuracy: 0.6842 - val_classification_auprc: 0.6676 - val_classification_loss: 0.6395 - val_classification_precision: 0.7273 - val_classification_recall: 0.4706 - val_loss: 1.8466 - val_segmentation_dice_coef_multiclass: 0.7649 - val_segmentation_iou_multiclass: 0.6538 - val_segmentation_loss: 0.2351 - learning_rate: 2.5000e-05
# Epoch 33/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 735ms/step - classification_accuracy: 0.5718 - classification_auprc: 0.6164 - classification_loss: 0.7208 - classification_precision: 0.5720 - classification_recall: 0.5740 - loss: 2.0366 - segmentation_dice_coef_multiclass: 0.7956 - segmentation_iou_multiclass: 0.6974 - segmentation_loss: 0.2044 - val_classification_accuracy: 0.6930 - val_classification_auprc: 0.6840 - val_classification_loss: 0.6214 - val_classification_precision: 0.7500 - val_classification_recall: 0.4706 - val_loss: 1.7984 - val_segmentation_dice_coef_multiclass: 0.7662 - val_segmentation_iou_multiclass: 0.6553 - val_segmentation_loss: 0.2338 - learning_rate: 2.5000e-05
# Epoch 34/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 722ms/step - classification_accuracy: 0.5715 - classification_auprc: 0.5950 - classification_loss: 0.7589 - classification_precision: 0.6189 - classification_recall: 0.5750 - loss: 2.1299 - segmentation_dice_coef_multiclass: 0.7976 - segmentation_iou_multiclass: 0.6992 - segmentation_loss: 0.2024 - val_classification_accuracy: 0.7105 - val_classification_auprc: 0.6656 - val_classification_loss: 0.6291 - val_classification_precision: 0.7143 - val_classification_recall: 0.5882 - val_loss: 1.8191 - val_segmentation_dice_coef_multiclass: 0.7637 - val_segmentation_iou_multiclass: 0.6526 - val_segmentation_loss: 0.2363 - learning_rate: 2.5000e-05
# Epoch 35/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 699ms/step - classification_accuracy: 0.5487 - classification_auprc: 0.5911 - classification_loss: 0.7349 - classification_precision: 0.5451 - classification_recall: 0.5564 - loss: 2.0657 - segmentation_dice_coef_multiclass: 0.8019 - segmentation_iou_multiclass: 0.7049 - segmentation_loss: 0.1981 - val_classification_accuracy: 0.6930 - val_classification_auprc: 0.6616 - val_classification_loss: 0.6253 - val_classification_precision: 0.6739 - val_classification_recall: 0.6078 - val_loss: 1.7823 - val_segmentation_dice_coef_multiclass: 0.7944 - val_segmentation_iou_multiclass: 0.6928 - val_segmentation_loss: 0.2056 - learning_rate: 2.5000e-05
# Epoch 36/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 708ms/step - classification_accuracy: 0.6041 - classification_auprc: 0.6505 - classification_loss: 0.6851 - classification_precision: 0.5942 - classification_recall: 0.6479 - loss: 1.9374 - segmentation_dice_coef_multiclass: 0.8056 - segmentation_iou_multiclass: 0.7085 - segmentation_loss: 0.1944 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6386 - val_classification_loss: 0.6263 - val_classification_precision: 0.6071 - val_classification_recall: 0.6667 - val_loss: 1.7973 - val_segmentation_dice_coef_multiclass: 0.7933 - val_segmentation_iou_multiclass: 0.6912 - val_segmentation_loss: 0.2067 - learning_rate: 2.5000e-05
# Epoch 37/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 709ms/step - classification_accuracy: 0.5840 - classification_auprc: 0.5769 - classification_loss: 0.7478 - classification_precision: 0.5867 - classification_recall: 0.6004 - loss: 2.0940 - segmentation_dice_coef_multiclass: 0.8059 - segmentation_iou_multiclass: 0.7091 - segmentation_loss: 0.1941 - val_classification_accuracy: 0.5702 - val_classification_auprc: 0.6517 - val_classification_loss: 0.6411 - val_classification_precision: 0.5208 - val_classification_recall: 0.4902 - val_loss: 1.8166 - val_segmentation_dice_coef_multiclass: 0.7897 - val_segmentation_iou_multiclass: 0.6846 - val_segmentation_loss: 0.2103 - learning_rate: 2.5000e-05
# Epoch 38/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 39s 680ms/step - classification_accuracy: 0.5727 - classification_auprc: 0.5888 - classification_loss: 0.7368 - classification_precision: 0.6072 - classification_recall: 0.5715 - loss: 2.0695 - segmentation_dice_coef_multiclass: 0.8027 - segmentation_iou_multiclass: 0.7038 - segmentation_loss: 0.1973 - val_classification_accuracy: 0.6754 - val_classification_auprc: 0.5828 - val_classification_loss: 0.6285 - val_classification_precision: 0.6207 - val_classification_recall: 0.7059 - val_loss: 1.8159 - val_segmentation_dice_coef_multiclass: 0.8010 - val_segmentation_iou_multiclass: 0.6997 - val_segmentation_loss: 0.1990 - learning_rate: 2.5000e-05
# Epoch 39/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 703ms/step - classification_accuracy: 0.5999 - classification_auprc: 0.6266 - classification_loss: 0.7122 - classification_precision: 0.6210 - classification_recall: 0.6220 - loss: 2.0030 - segmentation_dice_coef_multiclass: 0.8077 - segmentation_iou_multiclass: 0.7108 - segmentation_loss: 0.1923 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.6246 - val_classification_loss: 0.6388 - val_classification_precision: 0.5745 - val_classification_recall: 0.5294 - val_loss: 1.8257 - val_segmentation_dice_coef_multiclass: 0.7960 - val_segmentation_iou_multiclass: 0.6928 - val_segmentation_loss: 0.2040 - learning_rate: 2.5000e-05
# Epoch 40/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 728ms/step - classification_accuracy: 0.5585 - classification_auprc: 0.5694 - classification_loss: 0.7738 - classification_precision: 0.5783 - classification_recall: 0.6363 - loss: 2.1630 - segmentation_dice_coef_multiclass: 0.8017 - segmentation_iou_multiclass: 0.7014 - segmentation_loss: 0.1983 - val_classification_accuracy: 0.5702 - val_classification_auprc: 0.6046 - val_classification_loss: 0.6515 - val_classification_precision: 0.5217 - val_classification_recall: 0.4706 - val_loss: 1.8788 - val_segmentation_dice_coef_multiclass: 0.7840 - val_segmentation_iou_multiclass: 0.6759 - val_segmentation_loss: 0.2160 - learning_rate: 2.5000e-05
# Epoch 41/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 80s 699ms/step - classification_accuracy: 0.5801 - classification_auprc: 0.6110 - classification_loss: 0.7370 - classification_precision: 0.5905 - classification_recall: 0.6356 - loss: 2.0666 - segmentation_dice_coef_multiclass: 0.8061 - segmentation_iou_multiclass: 0.7070 - segmentation_loss: 0.1939 - val_classification_accuracy: 0.6667 - val_classification_auprc: 0.5923 - val_classification_loss: 0.6335 - val_classification_precision: 0.6102 - val_classification_recall: 0.7059 - val_loss: 1.8436 - val_segmentation_dice_coef_multiclass: 0.7985 - val_segmentation_iou_multiclass: 0.6956 - val_segmentation_loss: 0.2015 - learning_rate: 2.5000e-05
# Epoch 42/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 710ms/step - classification_accuracy: 0.5213 - classification_auprc: 0.5423 - classification_loss: 0.7825 - classification_precision: 0.5302 - classification_recall: 0.5785 - loss: 2.1795 - segmentation_dice_coef_multiclass: 0.8070 - segmentation_iou_multiclass: 0.7071 - segmentation_loss: 0.1930 - val_classification_accuracy: 0.6667 - val_classification_auprc: 0.5917 - val_classification_loss: 0.6504 - val_classification_precision: 0.6182 - val_classification_recall: 0.6667 - val_loss: 1.8667 - val_segmentation_dice_coef_multiclass: 0.8002 - val_segmentation_iou_multiclass: 0.6963 - val_segmentation_loss: 0.1998 - learning_rate: 2.5000e-05
# Epoch 43/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - classification_accuracy: 0.4765 - classification_auprc: 0.5655 - classification_loss: 0.8079 - classification_precision: 0.5316 - classification_recall: 0.4710 - loss: 2.2365 - segmentation_dice_coef_multiclass: 0.8135 - segmentation_iou_multiclass: 0.7161 - segmentation_loss: 0.1865
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 712ms/step - classification_accuracy: 0.4770 - classification_auprc: 0.5655 - classification_loss: 0.8074 - classification_precision: 0.5314 - classification_recall: 0.4717 - loss: 2.2352 - segmentation_dice_coef_multiclass: 0.8135 - segmentation_iou_multiclass: 0.7161 - segmentation_loss: 0.1865 - val_classification_accuracy: 0.6316 - val_classification_auprc: 0.5951 - val_classification_loss: 0.6399 - val_classification_precision: 0.5882 - val_classification_recall: 0.5882 - val_loss: 1.8381 - val_segmentation_dice_coef_multiclass: 0.7957 - val_segmentation_iou_multiclass: 0.6902 - val_segmentation_loss: 0.2043 - learning_rate: 2.5000e-05
# Epoch 44/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 688ms/step - classification_accuracy: 0.6013 - classification_auprc: 0.6535 - classification_loss: 0.6854 - classification_precision: 0.6078 - classification_recall: 0.5796 - loss: 1.9271 - segmentation_dice_coef_multiclass: 0.8167 - segmentation_iou_multiclass: 0.7199 - segmentation_loss: 0.1833 - val_classification_accuracy: 0.5965 - val_classification_auprc: 0.5638 - val_classification_loss: 0.6710 - val_classification_precision: 0.5439 - val_classification_recall: 0.6078 - val_loss: 1.9104 - val_segmentation_dice_coef_multiclass: 0.8005 - val_segmentation_iou_multiclass: 0.6967 - val_segmentation_loss: 0.1995 - learning_rate: 1.2500e-05
# Epoch 45/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 722ms/step - classification_accuracy: 0.5403 - classification_auprc: 0.6011 - classification_loss: 0.7487 - classification_precision: 0.5666 - classification_recall: 0.5574 - loss: 2.0811 - segmentation_dice_coef_multiclass: 0.8209 - segmentation_iou_multiclass: 0.7260 - segmentation_loss: 0.1791 - val_classification_accuracy: 0.6228 - val_classification_auprc: 0.5959 - val_classification_loss: 0.6487 - val_classification_precision: 0.5800 - val_classification_recall: 0.5686 - val_loss: 1.8433 - val_segmentation_dice_coef_multiclass: 0.8037 - val_segmentation_iou_multiclass: 0.7008 - val_segmentation_loss: 0.1963 - learning_rate: 1.2500e-05
# Epoch 46/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 79s 668ms/step - classification_accuracy: 0.5629 - classification_auprc: 0.5923 - classification_loss: 0.7345 - classification_precision: 0.5729 - classification_recall: 0.5904 - loss: 2.0471 - segmentation_dice_coef_multiclass: 0.8194 - segmentation_iou_multiclass: 0.7234 - segmentation_loss: 0.1806 - val_classification_accuracy: 0.6228 - val_classification_auprc: 0.6148 - val_classification_loss: 0.6326 - val_classification_precision: 0.5952 - val_classification_recall: 0.4902 - val_loss: 1.8008 - val_segmentation_dice_coef_multiclass: 0.8028 - val_segmentation_iou_multiclass: 0.6987 - val_segmentation_loss: 0.1972 - learning_rate: 1.2500e-05
# Epoch 47/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 710ms/step - classification_accuracy: 0.5371 - classification_auprc: 0.5716 - classification_loss: 0.7261 - classification_precision: 0.5217 - classification_recall: 0.5510 - loss: 2.0217 - segmentation_dice_coef_multiclass: 0.8238 - segmentation_iou_multiclass: 0.7290 - segmentation_loss: 0.1762 - val_classification_accuracy: 0.6491 - val_classification_auprc: 0.6109 - val_classification_loss: 0.6292 - val_classification_precision: 0.6279 - val_classification_recall: 0.5294 - val_loss: 1.8118 - val_segmentation_dice_coef_multiclass: 0.7966 - val_segmentation_iou_multiclass: 0.6909 - val_segmentation_loss: 0.2034 - learning_rate: 1.2500e-05
# Epoch 48/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 714ms/step - classification_accuracy: 0.6087 - classification_auprc: 0.6530 - classification_loss: 0.7273 - classification_precision: 0.6262 - classification_recall: 0.6480 - loss: 2.0241 - segmentation_dice_coef_multiclass: 0.8244 - segmentation_iou_multiclass: 0.7300 - segmentation_loss: 0.1756 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.6245 - val_classification_loss: 0.6352 - val_classification_precision: 0.5686 - val_classification_recall: 0.5686 - val_loss: 1.8218 - val_segmentation_dice_coef_multiclass: 0.8060 - val_segmentation_iou_multiclass: 0.7028 - val_segmentation_loss: 0.1940 - learning_rate: 1.2500e-05
# Epoch 49/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 39s 682ms/step - classification_accuracy: 0.6013 - classification_auprc: 0.5725 - classification_loss: 0.7221 - classification_precision: 0.5650 - classification_recall: 0.6971 - loss: 2.0098 - segmentation_dice_coef_multiclass: 0.8255 - segmentation_iou_multiclass: 0.7317 - segmentation_loss: 0.1745 - val_classification_accuracy: 0.6228 - val_classification_auprc: 0.5917 - val_classification_loss: 0.6465 - val_classification_precision: 0.5800 - val_classification_recall: 0.5686 - val_loss: 1.8534 - val_segmentation_dice_coef_multiclass: 0.8068 - val_segmentation_iou_multiclass: 0.7037 - val_segmentation_loss: 0.1932 - learning_rate: 1.2500e-05
# Epoch 50/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 44s 730ms/step - classification_accuracy: 0.6047 - classification_auprc: 0.6469 - classification_loss: 0.6856 - classification_precision: 0.6046 - classification_recall: 0.6281 - loss: 1.9245 - segmentation_dice_coef_multiclass: 0.8197 - segmentation_iou_multiclass: 0.7242 - segmentation_loss: 0.1803 - val_classification_accuracy: 0.6228 - val_classification_auprc: 0.5682 - val_classification_loss: 0.6572 - val_classification_precision: 0.5769 - val_classification_recall: 0.5882 - val_loss: 1.8727 - val_segmentation_dice_coef_multiclass: 0.8059 - val_segmentation_iou_multiclass: 0.7011 - val_segmentation_loss: 0.1941 - learning_rate: 1.2500e-05
# Epoch 51/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - classification_accuracy: 0.6126 - classification_auprc: 0.6391 - classification_loss: 0.7381 - classification_precision: 0.6318 - classification_recall: 0.6290 - loss: 2.0463 - segmentation_dice_coef_multiclass: 0.8292 - segmentation_iou_multiclass: 0.7365 - segmentation_loss: 0.1708
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 78s 663ms/step - classification_accuracy: 0.6126 - classification_auprc: 0.6390 - classification_loss: 0.7376 - classification_precision: 0.6315 - classification_recall: 0.6292 - loss: 2.0452 - segmentation_dice_coef_multiclass: 0.8291 - segmentation_iou_multiclass: 0.7364 - segmentation_loss: 0.1709 - val_classification_accuracy: 0.6404 - val_classification_auprc: 0.6230 - val_classification_loss: 0.6430 - val_classification_precision: 0.6087 - val_classification_recall: 0.5490 - val_loss: 1.8251 - val_segmentation_dice_coef_multiclass: 0.8118 - val_segmentation_iou_multiclass: 0.7101 - val_segmentation_loss: 0.1882 - learning_rate: 1.2500e-05
# Epoch 52/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 682ms/step - classification_accuracy: 0.6094 - classification_auprc: 0.6099 - classification_loss: 0.7516 - classification_precision: 0.6363 - classification_recall: 0.6266 - loss: 2.0843 - segmentation_dice_coef_multiclass: 0.8249 - segmentation_iou_multiclass: 0.7308 - segmentation_loss: 0.1751 - val_classification_accuracy: 0.6404 - val_classification_auprc: 0.6215 - val_classification_loss: 0.6337 - val_classification_precision: 0.6000 - val_classification_recall: 0.5882 - val_loss: 1.8089 - val_segmentation_dice_coef_multiclass: 0.8093 - val_segmentation_iou_multiclass: 0.7063 - val_segmentation_loss: 0.1907 - learning_rate: 6.2500e-06
# Epoch 53/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 713ms/step - classification_accuracy: 0.5847 - classification_auprc: 0.6029 - classification_loss: 0.7319 - classification_precision: 0.5917 - classification_recall: 0.6731 - loss: 2.0342 - segmentation_dice_coef_multiclass: 0.8257 - segmentation_iou_multiclass: 0.7319 - segmentation_loss: 0.1743 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6259 - val_classification_loss: 0.6339 - val_classification_precision: 0.6250 - val_classification_recall: 0.5882 - val_loss: 1.8044 - val_segmentation_dice_coef_multiclass: 0.8114 - val_segmentation_iou_multiclass: 0.7091 - val_segmentation_loss: 0.1886 - learning_rate: 6.2500e-06
# Epoch 54/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 719ms/step - classification_accuracy: 0.5468 - classification_auprc: 0.5820 - classification_loss: 0.7394 - classification_precision: 0.5542 - classification_recall: 0.5297 - loss: 2.0532 - segmentation_dice_coef_multiclass: 0.8256 - segmentation_iou_multiclass: 0.7309 - segmentation_loss: 0.1744 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6112 - val_classification_loss: 0.6282 - val_classification_precision: 0.6250 - val_classification_recall: 0.5882 - val_loss: 1.7948 - val_segmentation_dice_coef_multiclass: 0.8121 - val_segmentation_iou_multiclass: 0.7103 - val_segmentation_loss: 0.1879 - learning_rate: 6.2500e-06
# Epoch 55/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 696ms/step - classification_accuracy: 0.5702 - classification_auprc: 0.5965 - classification_loss: 0.7277 - classification_precision: 0.5598 - classification_recall: 0.5981 - loss: 2.0272 - segmentation_dice_coef_multiclass: 0.8223 - segmentation_iou_multiclass: 0.7261 - segmentation_loss: 0.1777 - val_classification_accuracy: 0.6667 - val_classification_auprc: 0.5995 - val_classification_loss: 0.6275 - val_classification_precision: 0.6327 - val_classification_recall: 0.6078 - val_loss: 1.7900 - val_segmentation_dice_coef_multiclass: 0.8136 - val_segmentation_iou_multiclass: 0.7115 - val_segmentation_loss: 0.1864 - learning_rate: 6.2500e-06
# Epoch 56/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 682ms/step - classification_accuracy: 0.5658 - classification_auprc: 0.6660 - classification_loss: 0.7259 - classification_precision: 0.6150 - classification_recall: 0.5744 - loss: 2.0154 - segmentation_dice_coef_multiclass: 0.8296 - segmentation_iou_multiclass: 0.7367 - segmentation_loss: 0.1704 - val_classification_accuracy: 0.6842 - val_classification_auprc: 0.6122 - val_classification_loss: 0.6176 - val_classification_precision: 0.6596 - val_classification_recall: 0.6078 - val_loss: 1.7665 - val_segmentation_dice_coef_multiclass: 0.8141 - val_segmentation_iou_multiclass: 0.7129 - val_segmentation_loss: 0.1859 - learning_rate: 6.2500e-06
# Epoch 57/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 675ms/step - classification_accuracy: 0.5883 - classification_auprc: 0.6217 - classification_loss: 0.7200 - classification_precision: 0.6021 - classification_recall: 0.6046 - loss: 2.0070 - segmentation_dice_coef_multiclass: 0.8233 - segmentation_iou_multiclass: 0.7274 - segmentation_loss: 0.1767 - val_classification_accuracy: 0.6667 - val_classification_auprc: 0.6134 - val_classification_loss: 0.6311 - val_classification_precision: 0.6226 - val_classification_recall: 0.6471 - val_loss: 1.8005 - val_segmentation_dice_coef_multiclass: 0.8137 - val_segmentation_iou_multiclass: 0.7119 - val_segmentation_loss: 0.1863 - learning_rate: 6.2500e-06
# Epoch 58/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 718ms/step - classification_accuracy: 0.5503 - classification_auprc: 0.6248 - classification_loss: 0.7865 - classification_precision: 0.5976 - classification_recall: 0.5636 - loss: 2.1684 - segmentation_dice_coef_multiclass: 0.8279 - segmentation_iou_multiclass: 0.7338 - segmentation_loss: 0.1721 - val_classification_accuracy: 0.6491 - val_classification_auprc: 0.6214 - val_classification_loss: 0.6375 - val_classification_precision: 0.6000 - val_classification_recall: 0.6471 - val_loss: 1.8199 - val_segmentation_dice_coef_multiclass: 0.8140 - val_segmentation_iou_multiclass: 0.7122 - val_segmentation_loss: 0.1860 - learning_rate: 6.2500e-06
# Epoch 59/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 79s 665ms/step - classification_accuracy: 0.5998 - classification_auprc: 0.5868 - classification_loss: 0.7208 - classification_precision: 0.6081 - classification_recall: 0.5922 - loss: 2.0033 - segmentation_dice_coef_multiclass: 0.8290 - segmentation_iou_multiclass: 0.7352 - segmentation_loss: 0.1710 - val_classification_accuracy: 0.6228 - val_classification_auprc: 0.6053 - val_classification_loss: 0.6480 - val_classification_precision: 0.5741 - val_classification_recall: 0.6078 - val_loss: 1.8527 - val_segmentation_dice_coef_multiclass: 0.8116 - val_segmentation_iou_multiclass: 0.7087 - val_segmentation_loss: 0.1884 - learning_rate: 6.2500e-06
# Epoch 60/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 679ms/step - classification_accuracy: 0.6156 - classification_auprc: 0.5672 - classification_loss: 0.7194 - classification_precision: 0.5815 - classification_recall: 0.6114 - loss: 1.9987 - segmentation_dice_coef_multiclass: 0.8300 - segmentation_iou_multiclass: 0.7366 - segmentation_loss: 0.1700 - val_classification_accuracy: 0.6404 - val_classification_auprc: 0.6166 - val_classification_loss: 0.6474 - val_classification_precision: 0.6000 - val_classification_recall: 0.5882 - val_loss: 1.8482 - val_segmentation_dice_coef_multiclass: 0.8105 - val_segmentation_iou_multiclass: 0.7074 - val_segmentation_loss: 0.1895 - learning_rate: 6.2500e-06
# Epoch 61/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 715ms/step - classification_accuracy: 0.5594 - classification_auprc: 0.5521 - classification_loss: 0.7683 - classification_precision: 0.5602 - classification_recall: 0.5774 - loss: 2.1199 - segmentation_dice_coef_multiclass: 0.8311 - segmentation_iou_multiclass: 0.7385 - segmentation_loss: 0.1689 - val_classification_accuracy: 0.6491 - val_classification_auprc: 0.6261 - val_classification_loss: 0.6455 - val_classification_precision: 0.6078 - val_classification_recall: 0.6078 - val_loss: 1.8458 - val_segmentation_dice_coef_multiclass: 0.8127 - val_segmentation_iou_multiclass: 0.7104 - val_segmentation_loss: 0.1873 - learning_rate: 6.2500e-06
# Epoch 62/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 720ms/step - classification_accuracy: 0.5651 - classification_auprc: 0.5775 - classification_loss: 0.7354 - classification_precision: 0.5675 - classification_recall: 0.5544 - loss: 2.0394 - segmentation_dice_coef_multiclass: 0.8292 - segmentation_iou_multiclass: 0.7360 - segmentation_loss: 0.1708 - val_classification_accuracy: 0.6404 - val_classification_auprc: 0.6125 - val_classification_loss: 0.6468 - val_classification_precision: 0.5962 - val_classification_recall: 0.6078 - val_loss: 1.8498 - val_segmentation_dice_coef_multiclass: 0.8136 - val_segmentation_iou_multiclass: 0.7111 - val_segmentation_loss: 0.1864 - learning_rate: 6.2500e-06
# Epoch 63/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 696ms/step - classification_accuracy: 0.6062 - classification_auprc: 0.6495 - classification_loss: 0.6631 - classification_precision: 0.6090 - classification_recall: 0.6087 - loss: 1.8549 - segmentation_dice_coef_multiclass: 0.8330 - segmentation_iou_multiclass: 0.7403 - segmentation_loss: 0.1670 - val_classification_accuracy: 0.6404 - val_classification_auprc: 0.5969 - val_classification_loss: 0.6492 - val_classification_precision: 0.6042 - val_classification_recall: 0.5686 - val_loss: 1.8608 - val_segmentation_dice_coef_multiclass: 0.8147 - val_segmentation_iou_multiclass: 0.7127 - val_segmentation_loss: 0.1853 - learning_rate: 6.2500e-06
# Epoch 64/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - classification_accuracy: 0.5598 - classification_auprc: 0.5772 - classification_loss: 0.7667 - classification_precision: 0.5582 - classification_recall: 0.6162 - loss: 2.1142 - segmentation_dice_coef_multiclass: 0.8327 - segmentation_iou_multiclass: 0.7408 - segmentation_loss: 0.1673
# Epoch 64: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 680ms/step - classification_accuracy: 0.5602 - classification_auprc: 0.5778 - classification_loss: 0.7658 - classification_precision: 0.5587 - classification_recall: 0.6164 - loss: 2.1121 - segmentation_dice_coef_multiclass: 0.8326 - segmentation_iou_multiclass: 0.7407 - segmentation_loss: 0.1674 - val_classification_accuracy: 0.6404 - val_classification_auprc: 0.6060 - val_classification_loss: 0.6466 - val_classification_precision: 0.6042 - val_classification_recall: 0.5686 - val_loss: 1.8526 - val_segmentation_dice_coef_multiclass: 0.8128 - val_segmentation_iou_multiclass: 0.7095 - val_segmentation_loss: 0.1872 - learning_rate: 6.2500e-06
# Epoch 65/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 39s 684ms/step - classification_accuracy: 0.5967 - classification_auprc: 0.7127 - classification_loss: 0.6611 - classification_precision: 0.6540 - classification_recall: 0.6161 - loss: 1.8523 - segmentation_dice_coef_multiclass: 0.8306 - segmentation_iou_multiclass: 0.7370 - segmentation_loss: 0.1694 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6093 - val_classification_loss: 0.6488 - val_classification_precision: 0.6200 - val_classification_recall: 0.6078 - val_loss: 1.8597 - val_segmentation_dice_coef_multiclass: 0.8154 - val_segmentation_iou_multiclass: 0.7131 - val_segmentation_loss: 0.1846 - learning_rate: 3.1250e-06
# Epoch 66/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 684ms/step - classification_accuracy: 0.5897 - classification_auprc: 0.6403 - classification_loss: 0.7048 - classification_precision: 0.5998 - classification_recall: 0.6220 - loss: 1.9613 - segmentation_dice_coef_multiclass: 0.8310 - segmentation_iou_multiclass: 0.7375 - segmentation_loss: 0.1690 - val_classification_accuracy: 0.6491 - val_classification_auprc: 0.6087 - val_classification_loss: 0.6433 - val_classification_precision: 0.6078 - val_classification_recall: 0.6078 - val_loss: 1.8448 - val_segmentation_dice_coef_multiclass: 0.8152 - val_segmentation_iou_multiclass: 0.7128 - val_segmentation_loss: 0.1848 - learning_rate: 3.1250e-06
# Epoch 67/200
# ...
# Epoch 36/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 705ms/step - classification_accuracy: 0.7040 - classification_auprc: 0.6896 - classification_loss: 0.6218 - classification_precision: 0.7134 - classification_recall: 0.6862 - loss: 1.7459 - segmentation_dice_coef_multiclass: 0.8389 - segmentation_iou_multiclass: 0.7426 - segmentation_loss: 0.1611 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.6959 - val_classification_loss: 0.6586 - val_classification_precision: 0.6944 - val_classification_recall: 0.4310 - val_loss: 1.8210 - val_segmentation_dice_coef_multiclass: 0.8155 - val_segmentation_iou_multiclass: 0.7067 - val_segmentation_loss: 0.1845 - learning_rate: 1.0000e-04
# Epoch 37/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 705ms/step - classification_accuracy: 0.6967 - classification_auprc: 0.7005 - classification_loss: 0.6200 - classification_precision: 0.6985 - classification_recall: 0.7249 - loss: 1.7380 - segmentation_dice_coef_multiclass: 0.8424 - segmentation_iou_multiclass: 0.7458 - segmentation_loss: 0.1576 - val_classification_accuracy: 0.5439 - val_classification_auprc: 0.6876 - val_classification_loss: 1.0274 - val_classification_precision: 0.8000 - val_classification_recall: 0.1379 - val_loss: 2.8798 - val_segmentation_dice_coef_multiclass: 0.6803 - val_segmentation_iou_multiclass: 0.5438 - val_segmentation_loss: 0.3197 - learning_rate: 1.0000e-04
# Epoch 38/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 739ms/step - classification_accuracy: 0.6863 - classification_auprc: 0.7829 - classification_loss: 0.5927 - classification_precision: 0.6836 - classification_recall: 0.7167 - loss: 1.6742 - segmentation_dice_coef_multiclass: 0.8379 - segmentation_iou_multiclass: 0.7388 - segmentation_loss: 0.1621 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.6360 - val_classification_loss: 0.6935 - val_classification_precision: 0.6250 - val_classification_recall: 0.6034 - val_loss: 2.0099 - val_segmentation_dice_coef_multiclass: 0.8050 - val_segmentation_iou_multiclass: 0.6904 - val_segmentation_loss: 0.1950 - learning_rate: 1.0000e-04
# Epoch 39/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 83s 755ms/step - classification_accuracy: 0.6750 - classification_auprc: 0.7050 - classification_loss: 0.6433 - classification_precision: 0.6497 - classification_recall: 0.7275 - loss: 1.7991 - segmentation_dice_coef_multiclass: 0.8395 - segmentation_iou_multiclass: 0.7401 - segmentation_loss: 0.1605 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.7578 - val_classification_loss: 0.5624 - val_classification_precision: 0.6508 - val_classification_recall: 0.7069 - val_loss: 1.7068 - val_segmentation_dice_coef_multiclass: 0.7594 - val_segmentation_iou_multiclass: 0.6292 - val_segmentation_loss: 0.2406 - learning_rate: 1.0000e-04
# Epoch 40/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 695ms/step - classification_accuracy: 0.7162 - classification_auprc: 0.7626 - classification_loss: 0.6123 - classification_precision: 0.7379 - classification_recall: 0.7024 - loss: 1.7165 - segmentation_dice_coef_multiclass: 0.8446 - segmentation_iou_multiclass: 0.7475 - segmentation_loss: 0.1554 - val_classification_accuracy: 0.6053 - val_classification_auprc: 0.6596 - val_classification_loss: 0.6707 - val_classification_precision: 0.6383 - val_classification_recall: 0.5172 - val_loss: 2.1028 - val_segmentation_dice_coef_multiclass: 0.6023 - val_segmentation_iou_multiclass: 0.4749 - val_segmentation_loss: 0.3977 - learning_rate: 1.0000e-04
# Epoch 41/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 736ms/step - classification_accuracy: 0.7406 - classification_auprc: 0.7732 - classification_loss: 0.5383 - classification_precision: 0.7235 - classification_recall: 0.7621 - loss: 1.5240 - segmentation_dice_coef_multiclass: 0.8523 - segmentation_iou_multiclass: 0.7574 - segmentation_loss: 0.1477 - val_classification_accuracy: 0.6579 - val_classification_auprc: 0.6614 - val_classification_loss: 0.6934 - val_classification_precision: 0.7209 - val_classification_recall: 0.5345 - val_loss: 2.1499 - val_segmentation_dice_coef_multiclass: 0.6229 - val_segmentation_iou_multiclass: 0.4632 - val_segmentation_loss: 0.3771 - learning_rate: 1.0000e-04
# Epoch 42/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 719ms/step - classification_accuracy: 0.7083 - classification_auprc: 0.7336 - classification_loss: 0.6005 - classification_precision: 0.7221 - classification_recall: 0.6813 - loss: 1.6806 - segmentation_dice_coef_multiclass: 0.8512 - segmentation_iou_multiclass: 0.7558 - segmentation_loss: 0.1488 - val_classification_accuracy: 0.5702 - val_classification_auprc: 0.7274 - val_classification_loss: 0.7861 - val_classification_precision: 0.5421 - val_classification_recall: 1.0000 - val_loss: 2.2578 - val_segmentation_dice_coef_multiclass: 0.7655 - val_segmentation_iou_multiclass: 0.6346 - val_segmentation_loss: 0.2345 - learning_rate: 1.0000e-04
# Epoch 43/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 82s 715ms/step - classification_accuracy: 0.6601 - classification_auprc: 0.6546 - classification_loss: 0.6733 - classification_precision: 0.6469 - classification_recall: 0.6978 - loss: 1.8710 - segmentation_dice_coef_multiclass: 0.8427 - segmentation_iou_multiclass: 0.7425 - segmentation_loss: 0.1573 - val_classification_accuracy: 0.7456 - val_classification_auprc: 0.7455 - val_classification_loss: 0.5159 - val_classification_precision: 0.6933 - val_classification_recall: 0.8966 - val_loss: 1.5354 - val_segmentation_dice_coef_multiclass: 0.7960 - val_segmentation_iou_multiclass: 0.6755 - val_segmentation_loss: 0.2040 - learning_rate: 1.0000e-04
# Epoch 44/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 699ms/step - classification_accuracy: 0.6517 - classification_auprc: 0.6677 - classification_loss: 0.6574 - classification_precision: 0.6578 - classification_recall: 0.5841 - loss: 1.8200 - segmentation_dice_coef_multiclass: 0.8538 - segmentation_iou_multiclass: 0.7593 - segmentation_loss: 0.1462 - val_classification_accuracy: 0.6228 - val_classification_auprc: 0.6883 - val_classification_loss: 0.6347 - val_classification_precision: 0.5882 - val_classification_recall: 0.8621 - val_loss: 1.8548 - val_segmentation_dice_coef_multiclass: 0.8180 - val_segmentation_iou_multiclass: 0.7044 - val_segmentation_loss: 0.1820 - learning_rate: 1.0000e-04
# Epoch 45/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 733ms/step - classification_accuracy: 0.6919 - classification_auprc: 0.7310 - classification_loss: 0.6356 - classification_precision: 0.7417 - classification_recall: 0.6708 - loss: 1.7640 - segmentation_dice_coef_multiclass: 0.8554 - segmentation_iou_multiclass: 0.7602 - segmentation_loss: 0.1446 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.7213 - val_classification_loss: 0.6277 - val_classification_precision: 0.6667 - val_classification_recall: 0.4828 - val_loss: 1.8997 - val_segmentation_dice_coef_multiclass: 0.7404 - val_segmentation_iou_multiclass: 0.6017 - val_segmentation_loss: 0.2596 - learning_rate: 1.0000e-04
# Epoch 46/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 724ms/step - classification_accuracy: 0.7819 - classification_auprc: 0.8154 - classification_loss: 0.5209 - classification_precision: 0.8039 - classification_recall: 0.7764 - loss: 1.4786 - segmentation_dice_coef_multiclass: 0.8541 - segmentation_iou_multiclass: 0.7577 - segmentation_loss: 0.1459 - val_classification_accuracy: 0.5263 - val_classification_auprc: 0.7485 - val_classification_loss: 1.3588 - val_classification_precision: 1.0000 - val_classification_recall: 0.0690 - val_loss: 3.6217 - val_segmentation_dice_coef_multiclass: 0.7830 - val_segmentation_iou_multiclass: 0.6560 - val_segmentation_loss: 0.2170 - learning_rate: 1.0000e-04
# Epoch 47/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 83s 746ms/step - classification_accuracy: 0.7203 - classification_auprc: 0.7820 - classification_loss: 0.5937 - classification_precision: 0.7255 - classification_recall: 0.7387 - loss: 1.6609 - segmentation_dice_coef_multiclass: 0.8537 - segmentation_iou_multiclass: 0.7569 - segmentation_loss: 0.1463 - val_classification_accuracy: 0.6930 - val_classification_auprc: 0.7606 - val_classification_loss: 0.5371 - val_classification_precision: 0.6769 - val_classification_recall: 0.7586 - val_loss: 1.8078 - val_segmentation_dice_coef_multiclass: 0.5622 - val_segmentation_iou_multiclass: 0.4011 - val_segmentation_loss: 0.4378 - learning_rate: 1.0000e-04
# Epoch 48/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 80s 717ms/step - classification_accuracy: 0.7627 - classification_auprc: 0.8007 - classification_loss: 0.5243 - classification_precision: 0.7503 - classification_recall: 0.7827 - loss: 1.4818 - segmentation_dice_coef_multiclass: 0.8593 - segmentation_iou_multiclass: 0.7644 - segmentation_loss: 0.1407 - val_classification_accuracy: 0.5702 - val_classification_auprc: 0.7350 - val_classification_loss: 0.8040 - val_classification_precision: 0.7647 - val_classification_recall: 0.2241 - val_loss: 2.3097 - val_segmentation_dice_coef_multiclass: 0.8204 - val_segmentation_iou_multiclass: 0.7066 - val_segmentation_loss: 0.1796 - learning_rate: 1.0000e-04
# Epoch 49/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 82s 718ms/step - classification_accuracy: 0.7751 - classification_auprc: 0.8504 - classification_loss: 0.4783 - classification_precision: 0.7886 - classification_recall: 0.7518 - loss: 1.3674 - segmentation_dice_coef_multiclass: 0.8587 - segmentation_iou_multiclass: 0.7637 - segmentation_loss: 0.1413 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.7143 - val_classification_loss: 0.7160 - val_classification_precision: 0.6094 - val_classification_recall: 0.6724 - val_loss: 2.0245 - val_segmentation_dice_coef_multiclass: 0.8163 - val_segmentation_iou_multiclass: 0.7015 - val_segmentation_loss: 0.1837 - learning_rate: 1.0000e-04
# Epoch 50/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 42s 735ms/step - classification_accuracy: 0.7433 - classification_auprc: 0.7997 - classification_loss: 0.5529 - classification_precision: 0.7538 - classification_recall: 0.7153 - loss: 1.5608 - segmentation_dice_coef_multiclass: 0.8518 - segmentation_iou_multiclass: 0.7527 - segmentation_loss: 0.1482 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.6474 - val_classification_loss: 0.9257 - val_classification_precision: 0.5714 - val_classification_recall: 0.9655 - val_loss: 2.4879 - val_segmentation_dice_coef_multiclass: 0.8152 - val_segmentation_iou_multiclass: 0.7003 - val_segmentation_loss: 0.1848 - learning_rate: 1.0000e-04
# Epoch 51/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 656ms/step - classification_accuracy: 0.6782 - classification_auprc: 0.7810 - classification_loss: 0.5878 - classification_precision: 0.6692 - classification_recall: 0.7167 - loss: 1.6422 - segmentation_dice_coef_multiclass: 0.8575 - segmentation_iou_multiclass: 0.7610 - segmentation_loss: 0.1425
# Epoch 51: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 715ms/step - classification_accuracy: 0.6787 - classification_auprc: 0.7810 - classification_loss: 0.5875 - classification_precision: 0.6695 - classification_recall: 0.7171 - loss: 1.6417 - segmentation_dice_coef_multiclass: 0.8574 - segmentation_iou_multiclass: 0.7610 - segmentation_loss: 0.1426 - val_classification_accuracy: 0.5263 - val_classification_auprc: 0.6930 - val_classification_loss: 1.0924 - val_classification_precision: 0.7000 - val_classification_recall: 0.1207 - val_loss: 2.9603 - val_segmentation_dice_coef_multiclass: 0.7815 - val_segmentation_iou_multiclass: 0.6521 - val_segmentation_loss: 0.2185 - learning_rate: 1.0000e-04
# Epoch 52/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 40s 700ms/step - classification_accuracy: 0.7446 - classification_auprc: 0.8294 - classification_loss: 0.5031 - classification_precision: 0.7220 - classification_recall: 0.7656 - loss: 1.4253 - segmentation_dice_coef_multiclass: 0.8628 - segmentation_iou_multiclass: 0.7690 - segmentation_loss: 0.1372 - val_classification_accuracy: 0.5439 - val_classification_auprc: 0.6908 - val_classification_loss: 0.8982 - val_classification_precision: 0.6667 - val_classification_recall: 0.2069 - val_loss: 2.5199 - val_segmentation_dice_coef_multiclass: 0.8189 - val_segmentation_iou_multiclass: 0.7050 - val_segmentation_loss: 0.1811 - learning_rate: 5.0000e-05
# Epoch 53/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 41s 698ms/step - classification_accuracy: 0.7948 - classification_auprc: 0.8709 - classification_loss: 0.4659 - classification_precision: 0.8144 - classification_recall: 0.7994 - loss: 1.3235 - segmentation_dice_coef_multiclass: 0.8716 - segmentation_iou_multiclass: 0.7826 - segmentation_loss: 0.1284 - val_classification_accuracy: 0.6228 - val_classification_auprc: 0.6801 - val_classification_loss: 0.7072 - val_classification_precision: 0.7027 - val_classification_recall: 0.4483 - val_loss: 1.9973 - val_segmentation_dice_coef_multiclass: 0.8340 - val_segmentation_iou_multiclass: 0.7253 - val_segmentation_loss: 0.1660 - learning_rate: 5.0000e-05
# Epoch 54/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 43s 742ms/step - classification_accuracy: 0.8331 - classification_auprc: 0.9106 - classification_loss: 0.3891 - classification_precision: 0.8294 - classification_recall: 0.8425 - loss: 1.1338 - segmentation_dice_coef_multiclass: 0.8693 - segmentation_iou_multiclass: 0.7790 - segmentation_loss: 0.1307 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.6866 - val_classification_loss: 0.7297 - val_classification_precision: 0.6842 - val_classification_recall: 0.4483 - val_loss: 2.0714 - val_segmentation_dice_coef_multiclass: 0.8241 - val_segmentation_iou_multiclass: 0.7109 - val_segmentation_loss: 0.1759 - learning_rate: 5.0000e-05
# Epoch 55/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 717ms/step - classification_accuracy: 0.7978 - classification_auprc: 0.9145 - classification_loss: 0.4361 - classification_precision: 0.8386 - classification_recall: 0.7812 - loss: 1.2459 - segmentation_dice_coef_multiclass: 0.8745 - segmentation_iou_multiclass: 0.7875 - segmentation_loss: 0.1255 - val_classification_accuracy: 0.5702 - val_classification_auprc: 0.7237 - val_classification_loss: 0.8351 - val_classification_precision: 0.6957 - val_classification_recall: 0.2759 - val_loss: 2.3369 - val_segmentation_dice_coef_multiclass: 0.8408 - val_segmentation_iou_multiclass: 0.7354 - val_segmentation_loss: 0.1592 - learning_rate: 5.0000e-05
# Epoch 56/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 82s 719ms/step - classification_accuracy: 0.8479 - classification_auprc: 0.9161 - classification_loss: 0.3812 - classification_precision: 0.8245 - classification_recall: 0.8715 - loss: 1.1100 - segmentation_dice_coef_multiclass: 0.8733 - segmentation_iou_multiclass: 0.7852 - segmentation_loss: 0.1267 - val_classification_accuracy: 0.6140 - val_classification_auprc: 0.7035 - val_classification_loss: 0.6999 - val_classification_precision: 0.6750 - val_classification_recall: 0.4655 - val_loss: 2.0202 - val_segmentation_dice_coef_multiclass: 0.8419 - val_segmentation_iou_multiclass: 0.7370 - val_segmentation_loss: 0.1581 - learning_rate: 5.0000e-05
# Epoch 57/200
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 82s 718ms/step - classification_accuracy: 0.8446 - classification_auprc: 0.9235 - classification_loss: 0.3833 - classification_precision: 0.8518 - classification_recall: 0.8497 - loss: 1.1160 - segmentation_dice_coef_multiclass: 0.8724 - segmentation_iou_multiclass: 0.7834 - segmentation_loss: 0.1276 - val_classification_accuracy: 0.6404 - val_classification_auprc: 0.6965 - val_classification_loss: 0.6994 - val_classification_precision: 0.6604 - val_classification_recall: 0.6034 - val_loss: 1.9711 - val_segmentation_dice_coef_multiclass: 0.8447 - val_segmentation_iou_multiclass: 0.7412 - val_segmentation_loss: 0.1553 - learning_rate: 5.0000e-05
# Epoch 58/200
# 20/57 ━━━━━━━━━━━━━━━━━━━━ 23s 638ms/step - classification_accuracy: 0.8605 - classification_auprc: 0.9412 - classification_loss: 0.3358 - classification_precision: 0.8585 - classification_recall: 0.8657 - loss: 0.9880 - segmentation_dice_coef_multiclass: 0.8816 - segmentation_iou_multiclass: 0.7980 - segmentation_loss: 0.1184
